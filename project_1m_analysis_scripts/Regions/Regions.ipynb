# %%
# Load the datasets from OceanDataCatalog

from OceanDataStore import OceanDataCatalog

catalog = OceanDataCatalog(catalog_name="noc-model-stac")

catalog.available_collections

#Era 5 probs the best here
# Out:
# ['noc-rapid-evolution', 'noc-npd-jra55', 'noc-npd-era5']

# %%
# Searching the ERA5 collection for sea surface temperature data

catalog.search(collection='noc-npd-era5', standard_name='sea_surface_temperature')

catalog.available_items

catalog.Items[5] 

# Near present run (1976 - 2024 (49 years))
# 0 for annual mean 1 degree
# 2 for annual mean 1/4 degree
# 5 for annual mean 1/12 degree
# Out:
#             * Item ID: noc-npd-era5/npd-eorca1-era5v1/gn/T1y
#               Title: eORCA1 ERA5v1 NPD T1y Icechunk repository
#               Description: Icechunk repository containing eORCA1 ERA5v1 NPD global ocean physics annual mean outputs defined at T-points.
#               Platform: gn
#               Start Date: 1976-01-01T00:00:00Z
#               End Date: 2025-07-31T00:00:00Z
#
#
#             * Item ID: noc-npd-era5/npd-eorca1-era5v1/gn/T1m
#               Title: eORCA1 ERA5v1 NPD T1m Icechunk repository
#               Description: Icechunk repository containing eORCA1 ERA5v1 NPD global ocean physics monthly mean outputs defined at T-points.
#               Platform: gn
#               Start Date: 1976-01-01T00:00:00Z
#               End Date: 2025-07-31T00:00:00Z
#
#
#             * Item ID: noc-npd-era5/npd-eorca025-era5v1/gn/T1y_3d
#               Title: eORCA025 ERA5v1 NPD T1y_3d Icechunk repository
#               Description: Icechunk repository containing eORCA025 ERA5v1 NPD global ocean physics annual mean outputs defined at T-points.
#               Platform: gn
#               Start Date: 1976-01-01T00:00:00Z
#               End Date: 2025-07-31T00:00:00Z
#
#
#             * Item ID: noc-npd-era5/npd-eorca025-era5v1/gn/T1m_3d
#               Title: eORCA025 ERA5v1 NPD T1m_3d Icechunk repository
#               Description: Icechunk repository containing eORCA025 ERA5v1 NPD global ocean physics monthly mean outputs defined at T-points.
#               Platform: gn
#               Start Date: 1976-01-01T00:00:00Z
#               End Date: 2025-07-31T00:00:00Z
#
#
#             * Item ID: noc-npd-era5/npd-eorca025-era5v1/gn/T5d_3d
#               Title: eORCA025 ERA5v1 NPD T5d_3d Icechunk repository
#               Description: Icechunk repository containing eORCA025 ERA5v1 NPD global ocean physics 5-day mean outputs defined at T-points.
#               Platform: gn
#               Start Date: 1976-01-01T00:00:00Z
#               End Date: 2025-07-31T00:00:00Z
#
#
#             * Item ID: noc-npd-era5/npd-eorca12-era5v1/gn/T1y_3d
#               Title: eORCA12 ERA5v1 NPD T1y_3d Icechunk repository
#               Description: Icechunk repository containing eORCA12 ERA5v1 NPD global ocean physics annual mean outputs defined at T-points.
#               Platform: gn
#               Start Date: 1976-01-01T00:00:00Z
#               End Date: 2025-06-30T00:00:00Z
#
#
#             * Item ID: noc-npd-era5/npd-eorca12-era5v1/gn/T1m_3d
#               Title: eORCA12 ERA5v1 NPD T1m_3d Icechunk repository
#               Description: Icechunk repository containing eORCA12 ERA5v1 NPD global ocean physics monthly mean outputs defined at T-points.
#               Platform: gn
#               Start Date: 1976-01-01T00:00:00Z
#               End Date: 2025-06-30T00:00:00Z
#
#
#             * Item ID: noc-npd-era5/npd-eorca12-era5v1/gn/T5d_3d
#               Title: eORCA12 ERA5v1 NPD T5d_3d Icechunk repository
#               Description: Icechunk repository containing eORCA12 ERA5v1 NPD global ocean physics 5-day mean outputs defined at T-points.
#               Platform: gn
#               Start Date: 1990-01-01T00:00:00Z
#               End Date: 2025-06-30T00:00:00Z
# <Item id=noc-npd-era5/npd-eorca12-era5v1/gn/T1y_3d>

# %%
# Create datasets (1, 025 and 12)

ds1 = catalog.open_dataset(id=catalog.Items[0].id,
                          start_datetime='1980-01',
                          end_datetime='1990-12',
                          )

ds1

ds025 = catalog.open_dataset(id=catalog.Items[2].id,
                          start_datetime='1980-01',
                          end_datetime='1990-12',
                          )

ds025

ds12 = catalog.open_dataset(id=catalog.Items[5].id,
                          start_datetime='1980-01',
                          end_datetime='1990-12',
                          )

ds12
# Out:
#   2026-03-13T16:37:45.692226Z  WARN aws_config::imds::region: failed to load region from IMDS, err: failed to load IMDS session token: dispatch failure: timeout: HTTP read timeout occurred after 1s: timed out (FailedToLoadToken(FailedToLoadToken { source: DispatchFailure(DispatchFailure { source: ConnectorError { kind: Timeout, source: HttpTimeoutError { kind: "HTTP read", duration: 1s }, connection: Unknown } }) }))
#     at /root/.cargo/registry/src/index.crates.io-1949cf8c6b5b557f/aws-config-1.8.12/src/imds/region.rs:66
#
#   2026-03-13T16:37:52.356531Z  WARN aws_config::imds::region: failed to load region from IMDS, err: failed to load IMDS session token: dispatch failure: timeout: HTTP read timeout occurred after 1s: timed out (FailedToLoadToken(FailedToLoadToken { source: DispatchFailure(DispatchFailure { source: ConnectorError { kind: Timeout, source: HttpTimeoutError { kind: "HTTP read", duration: 1s }, connection: Unknown } }) }))
#     at /root/.cargo/registry/src/index.crates.io-1949cf8c6b5b557f/aws-config-1.8.12/src/imds/region.rs:66
#
#   2026-03-13T16:37:56.114121Z  WARN aws_config::imds::region: failed to load region from IMDS, err: failed to load IMDS session token: dispatch failure: timeout: client error (Connect): HTTP connect timeout occurred after 1s: timed out (FailedToLoadToken(FailedToLoadToken { source: DispatchFailure(DispatchFailure { source: ConnectorError { kind: Timeout, source: hyper_util::client::legacy::Error(Connect, HttpTimeoutError { kind: "HTTP connect", duration: 1s }), connection: Unknown } }) }))
#     at /root/.cargo/registry/src/index.crates.io-1949cf8c6b5b557f/aws-config-1.8.12/src/imds/region.rs:66
# <xarray.Dataset> Size: 33GB
# Dimensions:                (time_counter: 11, y: 3605, x: 4320, axis_nbounds: 2)
# Coordinates:
#   * time_counter           (time_counter) datetime64[ns] 88B 1980-07-02 ... 1...
#     time_centered          (time_counter) datetime64[ns] 88B dask.array<chunksize=(1,), meta=np.ndarray>
#   * y                      (y) int64 29kB 0 1 2 3 4 ... 3600 3601 3602 3603 3604
#   * x                      (x) int64 35kB 0 1 2 3 4 ... 4315 4316 4317 4318 4319
#     nav_lon                (y, x) float64 125MB dask.array<chunksize=(3605, 4320), meta=np.ndarray>
#     nav_lat                (y, x) float64 125MB dask.array<chunksize=(3605, 4320), meta=np.ndarray>
# Dimensions without coordinates: axis_nbounds
# Data variables: (12/50)
#     hfls                   (time_counter, y, x) float32 685MB dask.array<chunksize=(1, 3605, 4320), meta=np.ndarray>
#     ficeberg               (time_counter, y, x) float32 685MB dask.array<chunksize=(1, 3605, 4320), meta=np.ndarray>
#     friver                 (time_counter, y, x) float32 685MB dask.array<chunksize=(1, 3605, 4320), meta=np.ndarray>
#     hfds                   (time_counter, y, x) float32 685MB dask.array<chunksize=(1, 3605, 4320), meta=np.ndarray>
#     hfevapds               (time_counter, y, x) float32 685MB dask.array<chunksize=(1, 3605, 4320), meta=np.ndarray>
#     hfempds                (time_counter, y, x) float32 685MB dask.array<chunksize=(1, 3605, 4320), meta=np.ndarray>
#     ...                     ...
#     time_counter_bounds    (time_counter, axis_nbounds) datetime64[ns] 176B dask.array<chunksize=(1, 2), meta=np.ndarray>
#     zossq                  (time_counter, y, x) float32 685MB dask.array<chunksize=(1, 3605, 4320), meta=np.ndarray>
#     tos_con                (time_counter, y, x) float32 685MB dask.array<chunksize=(1, 3605, 4320), meta=np.ndarray>
#     tossq_con              (time_counter, y, x) float32 685MB dask.array<chunksize=(1, 3605, 4320), meta=np.ndarray>
#     tnpeo                  (time_counter, y, x) float32 685MB dask.array<chunksize=(1, 3605, 4320), meta=np.ndarray>
#     zos                    (time_counter, y, x) float32 685MB dask.array<chunksize=(1, 3605, 4320), meta=np.ndarray>
# Attributes:
#     name:         OUTPUT/eORCA12_1y_grid_T
#     description:  ocean T grid variables
#     title:        ocean T grid variables
#     Conventions:  CF-1.6
#     timeStamp:    2025-Jul-25 08:11:05 GMT
#     uuid:         5f8a2e3f-ad60-4da9-a163-00af20a7ee65

# %%
# ~36N (1-degree) 
import matplotlib.pyplot as plt

# Time mean
da_mean = ds1['tos_con'].mean(dim='time_counter')

vmin = -2.0
vmax = 30.0

x_start, x_end = 185, 296
y_start, y_end = 198, 312

y_kill_start = 241
y_kill_end = 287
x_kill_start = 205
x_kill_end = 281

DS_kill = 250

RAPID = 229

da_crop = da_mean.isel(
    x=slice(x_start, x_end),
    y=slice(y_start, y_end)
)

# Restore original coordinates on the cropped array
da_crop = da_crop.assign_coords(
    x=ds1['tos_con'].x[x_start:x_end],
    y=ds1['tos_con'].y[y_start:y_end]
)

# Plot
fig, ax = plt.subplots(figsize=(6, 6))
da_crop.plot(ax=ax, cmap='RdBu_r', vmin=vmin, vmax=vmax)
plt.title('Mean SST (time-averaged) – index slice')

y_line = da_crop['y'].isel(y=y_kill_start - y_start).item()
ax.axhline(y=y_line, color='black', linestyle='--', linewidth=2)

y_line = da_crop['y'].isel(y=y_kill_end - y_start).item()
ax.axhline(y=y_line, color='black', linestyle='--', linewidth=2)

y_line = da_crop['y'].isel(y=RAPID - y_start).item()
ax.axhline(y=y_line, color='black', linestyle='--', linewidth=2)

x_line = da_crop['x'].isel(x=x_kill_start - x_start).item()
ax.axvline(x=x_line, color='black', linestyle='--', linewidth=2)

x_line = da_crop['x'].isel(x=x_kill_end - x_start).item()
ax.axvline(x=x_line, color='black', linestyle='--', linewidth=2)

x_line = da_crop['x'].isel(x=DS_kill - x_start).item()
ax.axvline(x=x_line, color='black', linestyle='--', linewidth=2)

plt.show()





# Convert to cropped array indices
y_idx = y_kill_start - y_start
x_idx_start = x_kill_start - x_start
x_idx_end = x_kill_end - x_start

y_RAPID = RAPID - y_start

# -----------------------------
# Slice the horizontal line segment (Dask-safe)
# -----------------------------
lat_line = da_crop['nav_lat'].isel(
    y=y_idx,
    x=slice(x_idx_start, x_idx_end)
).compute()  # forces Dask to load into memory

lat_RAPID = da_crop['nav_lat'].isel(
    y=y_RAPID,
    x=slice(x_idx_start, x_idx_end)
).compute()  # forces Dask to load into memory

# -----------------------------
# Compute average latitude
# -----------------------------
avg_lat = lat_line.mean().item()  
print("Average latitude:", avg_lat)

avg_lat_RAPID = lat_RAPID.mean().item()  
print("Average RAPID latitude:", avg_lat_RAPID)




x_start, x_end = 270, 290
y_start, y_end = 230, 250

da_crop = da_mean.isel(
    x=slice(x_start, x_end),
    y=slice(y_start, y_end)
)

# Restore original coordinates on the cropped array
da_crop = da_crop.assign_coords(
    x=ds1['tos_con'].x[x_start:x_end],
    y=ds1['tos_con'].y[y_start:y_end]
)

# Plot
fig, ax = plt.subplots(figsize=(6, 6))
da_crop.plot(ax=ax, cmap='RdBu_r', vmin=vmin, vmax=vmax)
plt.title('Mean SST (time-averaged) – index slice')

y_line = da_crop['y'].isel(y=y_kill_start - y_start).item()
ax.axhline(y=y_line, color='black', linestyle='--', linewidth=2)

x_line = da_crop['x'].isel(x=x_kill_end - x_start).item()
ax.axvline(x=x_line, color='black', linestyle='--', linewidth=2)

plt.show()



x_start, x_end = 200, 220
y_start, y_end = 220, 240

da_crop = da_mean.isel(
    x=slice(x_start, x_end),
    y=slice(y_start, y_end)
)

# Restore original coordinates on the cropped array
da_crop = da_crop.assign_coords(
    x=ds1['tos_con'].x[x_start:x_end],
    y=ds1['tos_con'].y[y_start:y_end]
)

# Plot
fig, ax = plt.subplots(figsize=(6, 6))
da_crop.plot(ax=ax, cmap='RdBu_r', vmin=vmin, vmax=vmax)
plt.title('Mean SST (time-averaged) – index slice')

y_line = da_crop['y'].isel(y=RAPID - y_start).item()
ax.axhline(y=y_line, color='black', linestyle='--', linewidth=2)

x_line = da_crop['x'].isel(x=x_kill_start - x_start).item()
ax.axvline(x=x_line, color='black', linestyle='--', linewidth=2)

plt.show()
# Out:
# Average latitude: 37.01578202573391
# Average RAPID latitude: 26.940216971249622

# %%
# ~36N (025-degree) 
import matplotlib.pyplot as plt

# Time mean
da_mean = ds025['tos_con'].mean(dim='time_counter')

vmin = -2.0
vmax = 30.0

x_start, x_end = 737, 1185
y_start, y_end = 695, 1128

y_kill_start = 844
y_kill_end = 1030
x_kill_start = 832
x_kill_end = 1125

DS_kill = 980

RAPID = 796

da_crop = da_mean.isel(
    x=slice(x_start, x_end),
    y=slice(y_start, y_end)
)

# Restore original coordinates on the cropped array
da_crop = da_crop.assign_coords(
    x=ds025['tos_con'].x[x_start:x_end],
    y=ds025['tos_con'].y[y_start:y_end]
)

# Plot
fig, ax = plt.subplots(figsize=(6, 6))
da_crop.plot(ax=ax, cmap='RdBu_r', vmin=vmin, vmax=vmax)
plt.title('Mean SST (time-averaged) – index slice')

y_line = da_crop['y'].isel(y=y_kill_start - y_start).item()
ax.axhline(y=y_line, color='black', linestyle='--', linewidth=2)

y_line = da_crop['y'].isel(y=y_kill_end - y_start).item()
ax.axhline(y=y_line, color='black', linestyle='--', linewidth=2)

y_line = da_crop['y'].isel(y=RAPID - y_start).item()
ax.axhline(y=y_line, color='black', linestyle='--', linewidth=2)

y_line = da_crop['y'].isel(y=y_kill_end - y_start).item()
ax.axhline(y=y_line, color='black', linestyle='--', linewidth=2)

x_line = da_crop['x'].isel(x=x_kill_start - x_start).item()
ax.axvline(x=x_line, color='black', linestyle='--', linewidth=2)

x_line = da_crop['x'].isel(x=x_kill_end - x_start).item()
ax.axvline(x=x_line, color='black', linestyle='--', linewidth=2)

x_line = da_crop['x'].isel(x=DS_kill - x_start).item()
ax.axvline(x=x_line, color='black', linestyle='--', linewidth=2)

plt.show()



# Convert to cropped array indices
y_idx = y_kill_start - y_start
x_idx_start = x_kill_start - x_start
x_idx_end = x_kill_end - x_start

y_RAPID = RAPID - y_start

# -----------------------------
# Slice the horizontal line segment (Dask-safe)
# -----------------------------
lat_line = da_crop['nav_lat'].isel(
    y=y_idx,
    x=slice(x_idx_start, x_idx_end)
).compute()  # forces Dask to load into memory

lat_RAPID = da_crop['nav_lat'].isel(
    y=y_RAPID,
    x=slice(x_idx_start, x_idx_end)
).compute()  # forces Dask to load into memory

# -----------------------------
# Compute average latitude
# -----------------------------
avg_lat = lat_line.mean().item()  
print("Average latitude:", avg_lat)

avg_lat_RAPID = lat_RAPID.mean().item()  
print("Average RAPID latitude:", avg_lat_RAPID)



x_start, x_end = 1100, 1150
y_start, y_end = 820, 870

da_crop = da_mean.isel(
    x=slice(x_start, x_end),
    y=slice(y_start, y_end)
)

# Restore original coordinates on the cropped array
da_crop = da_crop.assign_coords(
    x=ds025['tos_con'].x[x_start:x_end],
    y=ds025['tos_con'].y[y_start:y_end]
)

# Plot
fig, ax = plt.subplots(figsize=(6, 6))
da_crop.plot(ax=ax, cmap='RdBu_r', vmin=vmin, vmax=vmax)
plt.title('Mean SST (time-averaged) – index slice')

y_line = da_crop['y'].isel(y=y_kill_start - y_start).item()
ax.axhline(y=y_line, color='black', linestyle='--', linewidth=2)

#y_line = da_crop['y'].isel(y=y_kill_end - y_start).item()
#ax.axhline(y=y_line, color='black', linestyle='--', linewidth=2)

#x_line = da_crop['x'].isel(x=x_kill_start - x_start).item()
#ax.axvline(x=x_line, color='black', linestyle='--', linewidth=2)

x_line = da_crop['x'].isel(x=x_kill_end - x_start).item()
ax.axvline(x=x_line, color='black', linestyle='--', linewidth=2)

plt.show()
# Out:
# Average latitude: 37.029917657707934
# Average RAPID latitude: 26.942107565878587

# %%
# ~36N (12-degree) 
import matplotlib.pyplot as plt

# Time mean
da_mean = ds12['tos_con'].mean(dim='time_counter')

vmin = -2.0
vmax = 30.0

x_start, x_end = 2220, 3558
y_start, y_end = 2075, 3375

y_kill_start = 2521
y_kill_end = 3080
x_kill_start = 2500
x_kill_end = 3376

DS_kill = 2960

RAPID = 2377

da_crop = da_mean.isel(
    x=slice(x_start, x_end),
    y=slice(y_start, y_end)
)

# Restore original coordinates on the cropped array
da_crop = da_crop.assign_coords(
    x=ds12['tos_con'].x[x_start:x_end],
    y=ds12['tos_con'].y[y_start:y_end]
)

# Plot
fig, ax = plt.subplots(figsize=(6, 6))
da_crop.plot(ax=ax, cmap='RdBu_r', vmin=vmin, vmax=vmax)
plt.title('Mean SST (time-averaged) – index slice')

y_line = da_crop['y'].isel(y=y_kill_start - y_start).item()
ax.axhline(y=y_line, color='black', linestyle='--', linewidth=2)

y_line = da_crop['y'].isel(y=y_kill_end - y_start).item()
ax.axhline(y=y_line, color='black', linestyle='--', linewidth=2)

y_line = da_crop['y'].isel(y=RAPID - y_start).item()
ax.axhline(y=y_line, color='black', linestyle='--', linewidth=2)

x_line = da_crop['x'].isel(x=x_kill_start - x_start).item()
ax.axvline(x=x_line, color='black', linestyle='--', linewidth=2)

x_line = da_crop['x'].isel(x=x_kill_end - x_start).item()
ax.axvline(x=x_line, color='black', linestyle='--', linewidth=2)

x_line = da_crop['x'].isel(x=DS_kill - x_start).item()
ax.axvline(x=x_line, color='black', linestyle='--', linewidth=2)

plt.show()



# Convert to cropped array indices
y_idx = y_kill_start - y_start
x_idx_start = x_kill_start - x_start
x_idx_end = x_kill_end - x_start

y_RAPID = RAPID - y_start

# -----------------------------
# Slice the horizontal line segment (Dask-safe)
# -----------------------------
lat_line = da_crop['nav_lat'].isel(
    y=y_idx,
    x=slice(x_idx_start, x_idx_end)
).compute()  # forces Dask to load into memory

lat_RAPID = da_crop['nav_lat'].isel(
    y=y_RAPID,
    x=slice(x_idx_start, x_idx_end)
).compute()  # forces Dask to load into memory

# -----------------------------
# Compute average latitude
# -----------------------------
avg_lat = lat_line.mean().item()  
print("Average latitude:", avg_lat)

avg_lat_RAPID = lat_RAPID.mean().item()  
print("Average RAPID latitude:", avg_lat_RAPID)


x_start, x_end = 3300, 3400
y_start, y_end = 2450, 2550

da_crop = da_mean.isel(
    x=slice(x_start, x_end),
    y=slice(y_start, y_end)
)

# Restore original coordinates on the cropped array
da_crop = da_crop.assign_coords(
    x=ds12['tos_con'].x[x_start:x_end],
    y=ds12['tos_con'].y[y_start:y_end]
)

# Plot
fig, ax = plt.subplots(figsize=(6, 6))
da_crop.plot(ax=ax, cmap='RdBu_r', vmin=vmin, vmax=vmax)
plt.title('Mean SST (time-averaged) – index slice')

y_line = da_crop['y'].isel(y=y_kill_start - y_start).item()
ax.axhline(y=y_line, color='black', linestyle='--', linewidth=2)

#y_line = da_crop['y'].isel(y=y_kill_end - y_start).item()
#ax.axhline(y=y_line, color='black', linestyle='--', linewidth=2)

#x_line = da_crop['x'].isel(x=x_kill_start - x_start).item()
#ax.axvline(x=x_line, color='black', linestyle='--', linewidth=2)

x_line = da_crop['x'].isel(x=x_kill_end - x_start).item()
ax.axvline(x=x_line, color='black', linestyle='--', linewidth=2)

plt.show()
# Out:
# Average latitude: 37.03182465627313
# Average RAPID latitude: 26.94223471645895
